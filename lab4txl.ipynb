# %%
# ====== IMPORT ======
import pandas as pd
import numpy as np
import re
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder

# !pip install gensim
from gensim.models import Word2Vec

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab') # Added to resolve LookupError

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# ====== HÀM XỬ LÝ TEXT ======
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = nltk.word_tokenize(text)
    tokens = [w for w in tokens if w not in stop_words]
    return tokens

# ====== BÀI 1: HOTEL ======
df1 = pd.read_csv('ITA105_Lab_4_Hotel_reviews.csv')

df1 = df1.dropna()

for col in df1.select_dtypes(include='object').columns:
    if col != 'review_text': # Changed from 'review' to 'review_text'
        df1[col] = LabelEncoder().fit_transform(df1[col])

df1['tokens'] = df1['review_text'].apply(clean_text) # Changed from 'review' to 'review_text'

tfidf1 = TfidfVectorizer()
X1 = tfidf1.fit_transform(df1['review_text']) # Changed from 'review' to 'review_text'

model1 = Word2Vec(df1['tokens'], vector_size=100, window=5, min_count=1)

print("Bài 1 - gần nghĩa 'clean':")
print(model1.wv.most_similar('clean', topn=5))

# ====== BÀI 2: MATCH COMMENTS ======
df2 = pd.read_csv('ITA105_Lab_4_Match_comments.csv')

df2 = df2.dropna()

for col in df2.select_dtypes(include='object').columns:
    if col != 'comment':
        df2[col] = LabelEncoder().fit_transform(df2[col])

df2['tokens'] = df2['comment'].apply(clean_text)

tfidf2 = TfidfVectorizer()
X2 = tfidf2.fit_transform(df2['comment'])

model2 = Word2Vec(df2['tokens'], vector_size=100, window=5, min_count=1)

print("Bài 2 - gần nghĩa 'excellent':")
print(model2.wv.most_similar('excellent', topn=5))

# ====== BÀI 3: PLAYER FEEDBACK ======
df3 = pd.read_csv('ITA105_Lab_4_Player_feedback.csv')

df3 = df3.dropna()

for col in df3.select_dtypes(include='object').columns:
    if col != 'feedback':
        df3[col] = LabelEncoder().fit_transform(df3[col])

df3['tokens'] = df3['feedback'].apply(clean_text)

tfidf3 = TfidfVectorizer()
X3 = tfidf3.fit_transform(df3['feedback'])

model3 = Word2Vec(df3['tokens'], vector_size=100, window=5, min_count=1)

print("Bài 3 - gần nghĩa 'beautiful':")
print(model3.wv.most_similar('beautiful', topn=5))

# ====== BÀI 4: ALBUM ======
df4 = pd.read_csv('ITA105_Lab_4_Album_reviews.csv')

df4 = df4.dropna()

for col in df4.select_dtypes(include='object').columns:
    if col != 'review':
        df4[col] = LabelEncoder().fit_transform(df4[col])

df4['tokens'] = df4['review'].apply(clean_text)

tfidf4 = TfidfVectorizer()
X4 = tfidf4.fit_transform(df4['review'])

model4 = Word2Vec(df4['tokens'], vector_size=100, window=5, min_count=1)

print("Bài 4 - gần nghĩa 'creative':")
print(model4.wv.most_similar('creative', topn=5))
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Bài 1 - gần nghĩa 'clean':
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_8762/2384030457.py in <cell line: 0>()
#      42
#      43 print("Bài 1 - gần nghĩa 'clean':")
# ---> 44 print(model1.wv.most_similar('clean', topn=5))
#      45
#      46 # ====== BÀI 2: MATCH COMMENTS ======
#
# /usr/local/lib/python3.12/dist-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     841
# ...

# %%
# ====== IMPORT ======
import pandas as pd
import numpy as np
import re
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from gensim.models import Word2Vec

nltk.download('punkt')
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# ====== HÀM XỬ LÝ TEXT ======
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = nltk.word_tokenize(text)
    tokens = [w for w in tokens if w not in stop_words]
    return tokens

# ====== BÀI 1: HOTEL ======
df1 = pd.read_csv('ITA105_Lab_4_Hotel_reviews.csv')

df1 = df1.dropna()

for col in df1.select_dtypes(include='object').columns:
    if col != 'review':
        df1[col] = LabelEncoder().fit_transform(df1[col])

df1['tokens'] = df1['review'].apply(clean_text)

tfidf1 = TfidfVectorizer()
X1 = tfidf1.fit_transform(df1['review'])

model1 = Word2Vec(df1['tokens'], vector_size=100, window=5, min_count=1)

print("Bài 1 - gần nghĩa 'clean':")
print(model1.wv.most_similar('clean', topn=5))

# ====== BÀI 2: MATCH COMMENTS ======
df2 = pd.read_csv('ITA105_Lab_4_Match_comments.csv')

df2 = df2.dropna()

for col in df2.select_dtypes(include='object').columns:
    if col != 'comment':
        df2[col] = LabelEncoder().fit_transform(df2[col])

df2['tokens'] = df2['comment'].apply(clean_text)

tfidf2 = TfidfVectorizer()
X2 = tfidf2.fit_transform(df2['comment'])

model2 = Word2Vec(df2['tokens'], vector_size=100, window=5, min_count=1)

print("Bài 2 - gần nghĩa 'excellent':")
print(model2.wv.most_similar('excellent', topn=5))

# ====== BÀI 3: PLAYER FEEDBACK ======
df3 = pd.read_csv('ITA105_Lab_4_Player_feedback.csv')

df3 = df3.dropna()

for col in df3.select_dtypes(include='object').columns:
    if col != 'feedback':
        df3[col] = LabelEncoder().fit_transform(df3[col])

df3['tokens'] = df3['feedback'].apply(clean_text)

tfidf3 = TfidfVectorizer()
X3 = tfidf3.fit_transform(df3['feedback'])

model3 = Word2Vec(df3['tokens'], vector_size=100, window=5, min_count=1)

print("Bài 3 - gần nghĩa 'beautiful':")
print(model3.wv.most_similar('beautiful', topn=5))

# ====== BÀI 4: ALBUM ======
df4 = pd.read_csv('ITA105_Lab_4_Album_reviews.csv')

df4 = df4.dropna()

for col in df4.select_dtypes(include='object').columns:
    if col != 'review':
        df4[col] = LabelEncoder().fit_transform(df4[col])

df4['tokens'] = df4['review'].apply(clean_text)

tfidf4 = TfidfVectorizer()
X4 = tfidf4.fit_transform(df4['review'])

model4 = Word2Vec(df4['tokens'], vector_size=100, window=5, min_count=1)

print("Bài 4 - gần nghĩa 'creative':")
print(model4.wv.most_similar('creative', topn=5))
